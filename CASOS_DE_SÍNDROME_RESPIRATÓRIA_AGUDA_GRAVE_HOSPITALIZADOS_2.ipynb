# %% [markdown]
# <a href="https://colab.research.google.com/github/DeniseYuki/TCC/blob/main/CASOS_DE_S%C3%8DNDROME_RESPIRAT%C3%93RIA_AGUDA_GRAVE_HOSPITALIZADOS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CASOS DE SÍNDROME RESPIRATÓRIA AGUDA GRAVE HOSPITALIZADOS**

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import csv
from matplotlib import pyplot as plt

# %%
arquivo = pd.read_csv("INFLUD21-29-03-2021.csv", sep=";",low_memory = False)

# %%
arquivo.head(10)
# Out:
#    DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0  04/01/2021        1  03/01/2021        1        SP
# 1  04/01/2021        1  03/01/2021        1        SP
# 2  05/01/2021        1  04/01/2021        1        BA
# 3  04/01/2021        1  04/01/2021        1        SP
# 4  04/01/2021        1  03/01/2021        1        MG
# 5  11/01/2021        2  05/01/2021        1        SP
# 6  11/01/2021        2  09/01/2021        1        SP
# 7  06/01/2021        1  03/01/2021        1        SP
# 8  09/01/2021        1  07/01/2021        1        PR
# 9  12/01/2021        2  04/01/2021        1        SP
#
#                        ID_REGIONA  CO_REGIONA           ID_MUNICIP  \
# 0               GVE XVII CAMPINAS      1342.0             CAMPINAS
# 1   GVE XXVII SAO JOSE DOS CAMPOS      1351.0  SAO JOSE DOS CAMPOS
# 2  NUCLEO REGIONAL DE SAUDE LESTE      1380.0             SALVADOR
# 3                   GVE I CAPITAL      1331.0            SAO PAULO
# ...

# %%
x = arquivo.head(11) .iloc[:,6:12]
#arquivo.iloc[:,2:4]
x
# Out:
#     CO_REGIONA           ID_MUNICIP  CO_MUN_NOT  \
# 0       1342.0             CAMPINAS      350950
# 1       1351.0  SAO JOSE DOS CAMPOS      354990
# 2       1380.0             SALVADOR      292740
# 3       1331.0            SAO PAULO      355030
# 4       1449.0          MATEUS LEME      314070
# 5       1333.0            GUARULHOS      351880
# 6       1331.0            SAO PAULO      355030
# 7       1335.0      TABOAO DA SERRA      355280
# 8       1363.0           MATELANDIA      411560
# 9       1331.0            SAO PAULO      355030
# 10      1430.0             SAO LUIS      211130
#
#                                            ID_UNIDADE  CO_UNI_NOT
# 0                 HOSPITAL E MATERNIDADE CELSO PIERRO     2082128
# 1   DR RUBENS SAVASTANO HOSPITAL REGIONAL DE SAO J...     9491252
# 2                                HOSPITAL DO SUBURBIO     6595197
# 3   HOSPITAL KATIA DE SOUZA RODRIGUES TAIPAS SAO P...     2082225
# ...

# %%
x.plot()
# Out:
# <AxesSubplot:>
